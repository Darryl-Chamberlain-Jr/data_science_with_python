# %% [markdown]
# # Logistic Regression
#
# Logistic Regression (also known as logit regression) is a statistical method commonly used to model the probability of an event (dependent variable) occuring given some independent variables. These probabilities can be reported as-is or used as a binary classification. This uniquely situates Logistic Regressions as being able to both predict continuous variables AND be used for classification.

# %%
# import necessary functions from sklearn
from sklearn.datasets import load_wine
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split

# Load the wine dataset
wine = load_wine()
X_train, X_test, y_train, y_test = train_test_split(wine.data, wine.target, test_size=0.2)

# Create a decision tree classifier
reg_log = LogisticRegression()
reg_log.fit(X_train, y_train)
# Out:
# C:\Users\dcham\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
reg_log.predict_proba(X_test)
# This presents the probability of for all classes 
# For classification, we can classify by the highest probability class
# If we classify, we can calcuate our accuracy in classifying with this method
# Out:
# array([[9.15811163e-02, 2.25352999e-02, 8.85883584e-01],
#        [5.48167191e-05, 3.93692525e-07, 9.99944790e-01],
#        [2.59603282e-02, 9.05665010e-01, 6.83746621e-02],
#        [1.09913458e-03, 5.63189142e-06, 9.98895234e-01],
#        [9.99691767e-01, 1.25866522e-04, 1.82366013e-04],
#        [9.95986074e-01, 1.55158529e-03, 2.46234089e-03],
#        [7.94938674e-03, 2.46927198e-04, 9.91803686e-01],
#        [9.74424598e-03, 9.89076773e-01, 1.17898115e-03],
#        [4.09057050e-03, 9.95865913e-01, 4.35169079e-05],
#        [1.48015626e-02, 9.81979741e-01, 3.21869635e-03],
#        [1.37385402e-04, 9.99550053e-01, 3.12561333e-04],
#        [9.91718401e-01, 7.56507695e-03, 7.16521819e-04],
#        [4.84649726e-03, 9.95078181e-01, 7.53220543e-05],
#        [3.70829557e-01, 6.20142744e-01, 9.02769969e-03],
#        [9.81827875e-01, 2.52680795e-06, 1.81695986e-02],
#        [4.52821238e-01, 5.40468988e-01, 6.70977400e-03],
# ...

# %%
accuracy = reg_log.score(X_test, y_test)

print("Logistic Regression Accuracy:", f'{int(round(accuracy, 2)*100)}%')
# Out:
# Logistic Regression Accuracy: 97%
