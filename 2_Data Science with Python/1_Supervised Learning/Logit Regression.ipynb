# %% [markdown]
# # Logistic Regression
#
# Logistic Regression (also known as logit regression) is a statistical method commonly used to model the probability of an event (dependent variable) occuring given some independent variables. These probabilities can be reported as-is or used as a binary classification. This uniquely situates Logistic Regressions as being able to both predict continuous variables AND be used for classification.

# %%
# import necessary functions from sklearn
from sklearn.datasets import load_wine
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split

# Load the wine dataset
wine = load_wine()
X_train, X_test, y_train, y_test = train_test_split(wine.data, wine.target, test_size=0.2)

# Create a logistic regression classifier
reg_log = LogisticRegression()
reg_log.fit(X_train, y_train)
# Out:
# C:\Users\dcham\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
reg_log.predict_proba(X_test)
# This presents the probability of each outcome for all classes 
# For classification, we can classify by the highest probability class
# Out:
# array([[6.72116072e-05, 1.26177911e-05, 9.99920171e-01],
#        [1.09490978e-04, 9.99014479e-01, 8.76030290e-04],
#        [9.44718146e-02, 9.03872441e-01, 1.65574417e-03],
#        [4.76599095e-01, 5.20985692e-01, 2.41521208e-03],
#        [9.97975794e-01, 2.67521624e-06, 2.02153075e-03],
#        [9.92026386e-01, 7.78172634e-03, 1.91887748e-04],
#        [9.98859443e-01, 5.03561245e-06, 1.13552121e-03],
#        [9.30889195e-04, 2.09371594e-06, 9.99067017e-01],
#        [2.10002230e-03, 9.93143184e-01, 4.75679326e-03],
#        [9.98475700e-01, 5.38849535e-05, 1.47041531e-03],
#        [9.78746976e-01, 1.11739057e-03, 2.01356335e-02],
#        [4.13552650e-02, 9.23723952e-01, 3.49207834e-02],
#        [8.34458793e-04, 6.23794233e-03, 9.92927599e-01],
#        [2.25284198e-02, 9.73265470e-01, 4.20611036e-03],
#        [4.94743173e-03, 1.65871928e-04, 9.94886696e-01],
#        [9.99807112e-01, 9.54905350e-07, 1.91933136e-04],
#        [4.17000192e-04, 9.99566191e-01, 1.68085276e-05],
#        [9.85968339e-01, 1.31308438e-03, 1.27185769e-02],
#        [9.99942677e-01, 5.92549536e-09, 5.73174266e-05],
#        [8.28436147e-04, 9.98845839e-01, 3.25724557e-04],
#        [9.82707363e-01, 1.40101253e-02, 3.28251208e-03],
#        [3.36324707e-03, 9.95730435e-01, 9.06317900e-04],
#        [9.70260570e-04, 9.98641399e-01, 3.88340261e-04],
#        [9.93097298e-01, 3.04047886e-04, 6.59865436e-03],
#        [9.66224944e-01, 1.61306200e-06, 3.37734429e-02],
#        [9.57529278e-02, 8.55590461e-01, 4.86566115e-02],
#        [1.65241237e-03, 3.82488040e-02, 9.60098784e-01],
#        [7.68939595e-02, 9.06366423e-01, 1.67396176e-02],
#        [1.61697082e-05, 9.99981362e-01, 2.46817216e-06],
#        [9.99722282e-01, 1.07800969e-05, 2.66937924e-04],
#        [9.99565646e-01, 8.11596899e-06, 4.26237752e-04],
#        [2.08688550e-04, 1.65760266e-05, 9.99774735e-01],
#        [5.26432807e-03, 9.94325408e-01, 4.10264368e-04],
#        [1.93853706e-03, 7.44757863e-04, 9.97316705e-01],
#        [9.02947871e-05, 4.76298056e-04, 9.99433407e-01],
#        [1.17012596e-04, 1.03985888e-06, 9.99881948e-01]])

# %%
accuracy = reg_log.score(X_test, y_test)

print("Logistic Regression Accuracy:", f'{int(round(accuracy, 2)*100)}%')
# Out:
# Logistic Regression Accuracy: 97%
